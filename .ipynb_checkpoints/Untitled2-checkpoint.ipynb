# %%
# %%timeit -r 1 -n 10
# !python miniimagenet_train.py --epoch 40000 --task_num 5 --gpu_index 0
# Out:
# Namespace(epoch=40000, gpu_index='0', imgc=3, imgsz=84, k_qry=1, k_spt=1, meta_lr=0.001, n_way=2, task_num=5, update_lr=0.01, update_step=5, update_step_test=10)
# Meta(
#   (net): Learner(
#     conv2d:(ch_in:3, ch_out:32, k:3x3, stride:1, padding:0)
#     relu:(True,)
#     bn:(32,)
#     max_pool2d:(k:2, stride:2, padding:0)
#     conv2d:(ch_in:32, ch_out:32, k:3x3, stride:1, padding:0)
#     relu:(True,)
#     bn:(32,)
#     max_pool2d:(k:2, stride:2, padding:0)
#     conv2d:(ch_in:32, ch_out:32, k:3x3, stride:1, padding:0)
#     relu:(True,)
#     bn:(32,)
#     max_pool2d:(k:2, stride:2, padding:0)
#     conv2d:(ch_in:32, ch_out:32, k:3x3, stride:1, padding:0)
#     relu:(True,)
#     bn:(32,)
#     max_pool2d:(k:2, stride:1, padding:0)
#     flatten:()
#     linear:(in:800, out:2)
#
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 32x3x3x3 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
# ...
