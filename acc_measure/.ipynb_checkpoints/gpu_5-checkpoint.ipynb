# %%
gpu_idx = 5

# %%
task_nums = [50, 20, 10, 5]
i = gpu_idx
for task_num in task_nums:
    # !python train_net_cross_val.py --epoch 40000 --gpu_index {gpu_idx} --task_num {task_num} --mode 0 --cross_val_id {i}
# Out:
# Namespace(cross_val_idx=5, epoch=40000, gpu_index='5', imgc=3, imgsz=84, k_qry=1, k_spt=1, meta_lr=0.001, mode=0, n_way=2, task_num=50, update_lr=0.01, update_step=5, update_step_test=10)
# Total trainable tensors: 30498
# shuffle DB :train, b:10000, 2-way, 1-shot, 1-query, resize:84
# shuffle DB :val, b:100, 2-way, 1-shot, 1-query, resize:84
# step: 0 	training acc: [0.39 0.5  0.46 0.45 0.47 0.45]
# step: 0 	test acc: [0.465 0.53  0.505 0.545 0.54  0.53  0.51  0.525 0.515 0.525 0.51 ]
# step: 30 	training acc: [0.8  0.73 0.76 0.73 0.77 0.76]
# step: 60 	training acc: [0.82 0.74 0.71 0.74 0.74 0.73]
# step: 90 	training acc: [0.87 0.77 0.79 0.79 0.81 0.8 ]
# step: 120 	training acc: [0.91 0.87 0.87 0.86 0.87 0.87]
# step: 150 	training acc: [0.96 0.91 0.91 0.92 0.93 0.92]
# step: 180 	training acc: [0.91 0.86 0.89 0.89 0.89 0.88]
# step: 0 	training acc: [0.95 0.92 0.94 0.93 0.94 0.94]
# step: 0 	test acc: [0.925 0.895 0.89  0.875 0.89  0.88  0.88  0.88  0.88  0.88  0.885]
# step: 30 	training acc: [0.96 0.94 0.94 0.95 0.93 0.94]
# step: 60 	training acc: [0.95 0.92 0.92 0.93 0.92 0.93]
# step: 90 	training acc: [0.98 0.97 0.97 0.97 0.97 0.97]
# step: 120 	training acc: [0.97 0.95 0.96 0.96 0.96 0.96]
# step: 150 	training acc: [0.98 0.98 0.98 0.98 0.98 0.98]
# step: 180 	training acc: [0.97 0.95 0.95 0.95 0.95 0.95]
# step: 0 	training acc: [0.98 0.97 0.97 0.97 0.97 0.97]
# step: 0 	test acc: [0.95  0.93  0.93  0.925 0.93  0.925 0.93  0.925 0.925 0.925 0.925]
# step: 30 	training acc: [1.   0.99 0.99 0.99 0.99 0.99]
# step: 60 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 90 	training acc: [1.   1.   0.99 1.   0.99 0.99]
# step: 120 	training acc: [0.98 0.95 0.96 0.96 0.96 0.96]
# step: 150 	training acc: [0.99 0.99 0.99 0.99 0.99 0.99]
# step: 180 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 0 	training acc: [1.   0.98 0.98 0.98 0.98 0.98]
# step: 0 	test acc: [0.96 0.94 0.95 0.95 0.95 0.95 0.95 0.95 0.95 0.95 0.95]
# step: 30 	training acc: [1.   0.98 0.99 0.99 0.98 0.98]
# step: 60 	training acc: [1.   0.98 0.98 0.98 0.98 0.98]
# step: 90 	training acc: [1.   0.99 0.99 0.99 0.99 0.99]
# step: 120 	training acc: [1.   0.98 0.98 0.98 0.98 0.98]
# step: 150 	training acc: [1.   0.99 0.99 0.99 0.99 0.99]
# step: 180 	training acc: [1.   1.   1.   1.   1.   0.99]
# step: 199 	test acc: [0.97  0.945 0.94  0.945 0.94  0.94  0.94  0.94  0.94  0.94  0.94 ]
# Namespace(cross_val_idx=5, epoch=40000, gpu_index='5', imgc=3, imgsz=84, k_qry=1, k_spt=1, meta_lr=0.001, mode=0, n_way=2, task_num=20, update_lr=0.01, update_step=5, update_step_test=10)
# Total trainable tensors: 30498
# shuffle DB :train, b:10000, 2-way, 1-shot, 1-query, resize:84
# shuffle DB :val, b:100, 2-way, 1-shot, 1-query, resize:84
# step: 0 	training acc: [0.425 0.55  0.55  0.6   0.55  0.525]
# step: 0 	test acc: [0.51  0.49  0.475 0.49  0.495 0.495 0.485 0.495 0.49  0.49  0.495]
# step: 30 	training acc: [0.7   0.6   0.625 0.675 0.625 0.625]
# step: 60 	training acc: [0.85 0.65 0.65 0.65 0.65 0.65]
# step: 90 	training acc: [0.95  0.75  0.85  0.75  0.775 0.75 ]
# step: 120 	training acc: [0.75  0.75  0.65  0.7   0.675 0.675]
# step: 150 	training acc: [0.85  0.8   0.8   0.825 0.8   0.8  ]
# step: 180 	training acc: [0.925 0.925 0.9   0.875 0.875 0.875]
# step: 210 	training acc: [0.875 0.875 0.875 0.875 0.85  0.875]
# step: 240 	training acc: [0.95  0.95  0.925 0.925 0.925 0.925]
# step: 270 	training acc: [1.    0.925 0.925 0.95  0.925 0.925]
# step: 300 	training acc: [0.9   0.9   0.925 0.925 0.925 0.925]
# step: 330 	training acc: [0.975 0.95  0.975 0.975 0.975 0.975]
# step: 360 	training acc: [1.    0.95  0.95  0.925 0.925 0.925]
# step: 390 	training acc: [0.95  0.95  0.925 0.925 0.925 0.925]
# step: 420 	training acc: [0.95  0.95  0.925 0.95  0.925 0.95 ]
# step: 450 	training acc: [0.95  0.9   0.9   0.875 0.9   0.875]
# step: 480 	training acc: [0.925 0.95  0.975 1.    1.    1.   ]
# step: 0 	training acc: [1.    0.925 0.925 0.925 0.925 0.925]
# step: 0 	test acc: [0.935 0.92  0.925 0.93  0.93  0.93  0.93  0.925 0.925 0.93  0.93 ]
# step: 30 	training acc: [1.    0.95  0.975 0.975 0.975 0.975]
# step: 60 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 90 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 120 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 150 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 180 	training acc: [1.    0.975 0.975 0.975 0.975 0.975]
# step: 210 	training acc: [0.95  0.925 0.925 0.925 0.925 0.925]
# step: 240 	training acc: [1.    0.975 0.95  0.975 0.975 0.975]
# step: 270 	training acc: [1.    0.975 0.975 0.975 0.975 0.975]
# step: 300 	training acc: [0.95  0.925 0.95  0.95  0.95  0.95 ]
# step: 330 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 360 	training acc: [1.    0.975 0.975 0.975 0.975 0.975]
# step: 390 	training acc: [0.975 0.95  0.95  0.95  0.95  0.95 ]
# step: 420 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 450 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 480 	training acc: [0.975 0.95  0.95  0.95  0.95  0.95 ]
# step: 0 	training acc: [0.975 0.975 0.975 0.975 0.975 0.975]
# step: 0 	test acc: [0.93  0.94  0.93  0.935 0.935 0.935 0.935 0.935 0.935 0.93  0.935]
# step: 30 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 60 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 90 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 120 	training acc: [0.975 0.975 0.975 0.975 0.975 0.95 ]
# step: 150 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 180 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 210 	training acc: [1.    0.975 0.975 0.975 0.975 0.975]
# step: 240 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 270 	training acc: [0.975 0.975 0.975 0.975 0.975 0.975]
# step: 300 	training acc: [1.    0.975 0.975 1.    1.    1.   ]
# step: 330 	training acc: [1.    0.975 0.975 0.975 0.975 0.975]
# step: 360 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 390 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 420 	training acc: [1.    0.975 0.975 0.975 0.975 0.975]
# step: 450 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 480 	training acc: [1.    0.975 0.975 0.975 0.975 0.975]
# step: 0 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 0 	test acc: [0.91  0.95  0.945 0.95  0.95  0.95  0.95  0.95  0.95  0.95  0.95 ]
# step: 30 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 60 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 90 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 120 	training acc: [1.    0.975 0.975 0.975 0.975 0.975]
# step: 150 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 180 	training acc: [1.    1.    0.975 0.975 0.975 0.975]
# step: 210 	training acc: [0.975 1.    1.    1.    1.    1.   ]
# step: 240 	training acc: [1.    0.975 0.975 0.975 0.975 0.975]
# step: 270 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 300 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 330 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 360 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 390 	training acc: [0.975 0.9   0.9   0.9   0.9   0.9  ]
# step: 420 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 450 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 480 	training acc: [0.975 0.975 0.975 0.975 0.975 0.975]
# step: 499 	test acc: [0.94  0.94  0.935 0.935 0.935 0.935 0.935 0.935 0.935 0.93  0.93 ]
# Namespace(cross_val_idx=5, epoch=40000, gpu_index='5', imgc=3, imgsz=84, k_qry=1, k_spt=1, meta_lr=0.001, mode=0, n_way=2, task_num=10, update_lr=0.01, update_step=5, update_step_test=10)
# Total trainable tensors: 30498
# shuffle DB :train, b:10000, 2-way, 1-shot, 1-query, resize:84
# shuffle DB :val, b:100, 2-way, 1-shot, 1-query, resize:84
# step: 0 	training acc: [0.4  0.5  0.5  0.5  0.55 0.5 ]
# step: 0 	test acc: [0.495 0.48  0.51  0.52  0.53  0.53  0.53  0.52  0.525 0.52  0.52 ]
# step: 30 	training acc: [0.65 0.8  0.7  0.8  0.8  0.8 ]
# step: 60 	training acc: [0.7  0.75 0.7  0.75 0.7  0.7 ]
# step: 90 	training acc: [0.9  0.75 0.65 0.65 0.65 0.65]
# step: 120 	training acc: [0.65 0.6  0.55 0.55 0.6  0.6 ]
# step: 150 	training acc: [0.9  0.95 0.95 0.9  0.95 1.  ]
# step: 180 	training acc: [0.85 0.85 0.8  0.75 0.8  0.75]
# step: 210 	training acc: [0.75 0.8  0.7  0.7  0.7  0.7 ]
# step: 240 	training acc: [0.7  0.8  0.75 0.75 0.75 0.75]
# step: 270 	training acc: [0.95 1.   1.   1.   1.   1.  ]
# step: 300 	training acc: [0.8  0.8  0.75 0.75 0.75 0.75]
# step: 330 	training acc: [0.9  0.85 0.8  0.85 0.85 0.8 ]
# step: 360 	training acc: [0.85 0.95 0.95 0.95 0.95 0.9 ]
# step: 390 	training acc: [0.9  0.9  0.95 0.95 0.95 0.95]
# step: 420 	training acc: [0.95 0.9  0.95 0.95 0.95 0.95]
# step: 450 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 480 	training acc: [0.95 0.9  0.85 0.85 0.85 0.85]
# step: 500 	test acc: [0.915 0.895 0.89  0.895 0.9   0.895 0.895 0.9   0.9   0.9   0.895]
# step: 510 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 540 	training acc: [0.8  0.8  0.75 0.8  0.8  0.8 ]
# step: 570 	training acc: [0.75 0.85 0.85 0.85 0.85 0.85]
# step: 600 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 630 	training acc: [0.85 0.8  0.85 0.85 0.85 0.85]
# step: 660 	training acc: [0.95 0.9  0.95 0.95 0.95 0.95]
# step: 690 	training acc: [0.95 0.9  0.9  0.9  0.9  0.9 ]
# step: 720 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 750 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 780 	training acc: [0.95 0.85 0.85 0.85 0.85 0.85]
# step: 810 	training acc: [0.95 0.95 0.9  0.9  0.9  0.9 ]
# step: 840 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 870 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 900 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 930 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 960 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 990 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 0 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 0 	test acc: [0.975 0.965 0.965 0.965 0.965 0.965 0.965 0.965 0.965 0.965 0.965]
# step: 30 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 60 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 90 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 120 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 150 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 180 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 210 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 240 	training acc: [1.   1.   1.   1.   0.95 1.  ]
# step: 270 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 300 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 330 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 360 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 390 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 420 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 450 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 480 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 500 	test acc: [0.95  0.94  0.945 0.945 0.945 0.945 0.945 0.945 0.945 0.945 0.945]
# step: 510 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 540 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 570 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 600 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 630 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 660 	training acc: [1.  0.9 0.9 0.9 0.9 0.9]
# step: 690 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 720 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 750 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 780 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 810 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 840 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 870 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 900 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 930 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 960 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 990 	training acc: [0.95 1.   1.   1.   1.   1.  ]
# step: 0 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 0 	test acc: [0.965 0.97  0.97  0.97  0.97  0.97  0.97  0.97  0.97  0.97  0.97 ]
# step: 30 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 60 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 90 	training acc: [0.95 0.95 0.95 0.95 0.95 1.  ]
# step: 120 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 150 	training acc: [1.   0.95 0.95 0.95 0.9  0.9 ]
# step: 180 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 210 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 240 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 270 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 300 	training acc: [1.   0.95 1.   1.   1.   1.  ]
# step: 330 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 360 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 390 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 420 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 450 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 480 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 500 	test acc: [0.945 0.925 0.925 0.925 0.925 0.925 0.925 0.925 0.925 0.925 0.925]
# step: 510 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 540 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 570 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 600 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 630 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 660 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 690 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 720 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 750 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 780 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 810 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 840 	training acc: [0.95 1.   1.   1.   1.   1.  ]
# step: 870 	training acc: [1.  0.9 0.9 0.9 0.9 0.9]
# step: 900 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 930 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 960 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 990 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 0 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 0 	test acc: [0.975 0.96  0.96  0.96  0.96  0.96  0.96  0.96  0.96  0.96  0.96 ]
# step: 30 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 60 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 90 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 120 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 150 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 180 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 210 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 240 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 270 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 300 	training acc: [1.   0.95 0.95 0.95 0.95 0.95]
# step: 330 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 360 	training acc: [0.95 1.   1.   1.   1.   1.  ]
# step: 390 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 420 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 450 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 480 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 500 	test acc: [0.985 0.985 0.985 0.985 0.985 0.985 0.985 0.985 0.985 0.985 0.985]
# step: 510 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 540 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 570 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 600 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 630 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 660 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 690 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 720 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 750 	training acc: [0.95 0.95 0.95 0.95 0.95 0.95]
# step: 780 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 810 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 840 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 870 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 900 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 930 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 960 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 990 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 999 	test acc: [0.985 0.975 0.975 0.975 0.975 0.975 0.975 0.975 0.975 0.975 0.975]
# Namespace(cross_val_idx=5, epoch=40000, gpu_index='5', imgc=3, imgsz=84, k_qry=1, k_spt=1, meta_lr=0.001, mode=0, n_way=2, task_num=5, update_lr=0.01, update_step=5, update_step_test=10)
# Total trainable tensors: 30498
# shuffle DB :train, b:10000, 2-way, 1-shot, 1-query, resize:84
# shuffle DB :val, b:100, 2-way, 1-shot, 1-query, resize:84
# step: 0 	training acc: [0.4 0.5 0.4 0.4 0.5 0.5]
# step: 0 	test acc: [0.45  0.485 0.545 0.51  0.545 0.54  0.525 0.525 0.535 0.52  0.535]
# step: 30 	training acc: [0.8 0.6 0.7 0.6 0.7 0.6]
# step: 60 	training acc: [0.8 0.8 0.7 0.7 0.6 0.6]
# step: 90 	training acc: [1.  0.9 1.  1.  1.  1. ]
# step: 120 	training acc: [0.6 0.5 0.6 0.7 0.7 0.7]
# step: 150 	training acc: [0.8 0.9 0.8 0.7 0.7 0.7]
# step: 180 	training acc: [0.9 0.7 0.7 0.7 0.7 0.7]
# step: 210 	training acc: [0.6 0.5 0.6 0.6 0.6 0.6]
# step: 240 	training acc: [0.9 0.9 1.  0.9 1.  0.9]
# step: 270 	training acc: [1.  0.6 0.7 0.7 0.7 0.7]
# step: 300 	training acc: [1.  0.9 0.9 0.8 0.9 0.8]
# step: 330 	training acc: [0.9 0.8 0.9 0.8 0.8 0.8]
# step: 360 	training acc: [0.9 0.9 0.9 0.8 0.9 0.9]
# step: 390 	training acc: [0.9 1.  0.9 0.9 0.9 0.9]
# step: 420 	training acc: [1.  0.8 0.9 0.9 0.9 0.9]
# step: 450 	training acc: [0.7 0.8 0.8 0.8 0.8 0.8]
# step: 480 	training acc: [1.  0.7 0.8 0.8 0.8 0.8]
# step: 500 	test acc: [0.945 0.89  0.895 0.88  0.885 0.895 0.885 0.9   0.9   0.9   0.9  ]
# step: 510 	training acc: [0.8 0.8 0.7 0.7 0.7 0.7]
# step: 540 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 570 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 600 	training acc: [1.  0.8 0.8 0.8 0.8 0.8]
# step: 630 	training acc: [1.  0.8 0.8 0.8 0.8 0.8]
# step: 660 	training acc: [1.  0.9 1.  0.9 1.  1. ]
# step: 690 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 720 	training acc: [0.8 0.8 0.8 0.8 0.8 0.7]
# step: 750 	training acc: [0.9 1.  1.  1.  1.  1. ]
# step: 780 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 810 	training acc: [1.  1.  0.9 0.9 1.  1. ]
# step: 840 	training acc: [0.8 0.8 0.8 0.8 0.8 0.8]
# step: 870 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 900 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 930 	training acc: [0.9 0.9 1.  1.  1.  1. ]
# step: 960 	training acc: [1.  0.9 0.9 0.9 0.9 0.9]
# step: 990 	training acc: [1.  1.  0.8 0.8 0.8 0.8]
# step: 1000 	test acc: [0.95  0.9   0.915 0.91  0.91  0.91  0.91  0.91  0.91  0.91  0.91 ]
# step: 1020 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1050 	training acc: [1.  0.8 0.9 0.8 0.9 0.8]
# step: 1080 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1110 	training acc: [0.9 1.  1.  1.  1.  1. ]
# step: 1140 	training acc: [0.6 0.6 0.6 0.6 0.6 0.6]
# step: 1170 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1200 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1230 	training acc: [0.9 0.8 0.8 0.8 0.8 0.8]
# step: 1260 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1290 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1320 	training acc: [0.8 0.8 0.8 0.8 0.8 0.8]
# step: 1350 	training acc: [0.9 0.8 0.8 0.8 0.8 0.8]
# step: 1380 	training acc: [1.  0.9 0.9 0.9 0.9 0.9]
# step: 1410 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1440 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1470 	training acc: [1.  0.9 0.9 0.9 0.9 0.9]
# step: 1500 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 1500 	test acc: [0.94  0.915 0.915 0.915 0.915 0.915 0.915 0.915 0.915 0.915 0.915]
# step: 1530 	training acc: [0.8 0.9 0.9 0.8 0.8 0.8]
# step: 1560 	training acc: [0.8 0.8 0.8 0.8 0.8 0.8]
# step: 1590 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 1620 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1650 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1680 	training acc: [1.  0.9 0.9 0.9 0.9 0.9]
# step: 1710 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1740 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1770 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1800 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1830 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 1860 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1890 	training acc: [0.9 0.7 0.7 0.8 0.8 0.8]
# step: 1920 	training acc: [1.  0.9 1.  0.9 1.  1. ]
# step: 1950 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1980 	training acc: [0.9 1.  1.  1.  1.  1. ]
# step: 0 	training acc: [1.  0.9 0.9 0.9 0.9 0.9]
# step: 0 	test acc: [0.92  0.925 0.93  0.925 0.925 0.925 0.92  0.92  0.92  0.92  0.925]
# step: 30 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 60 	training acc: [1.  0.9 1.  0.9 1.  1. ]
# step: 90 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 120 	training acc: [1.  0.9 0.9 0.9 0.9 0.9]
# step: 150 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 180 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 210 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 240 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 270 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 300 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 330 	training acc: [1.  0.9 0.9 0.9 1.  1. ]
# step: 360 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 390 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 420 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 450 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 480 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 500 	test acc: [0.945 0.945 0.94  0.94  0.94  0.94  0.94  0.945 0.945 0.945 0.945]
# step: 510 	training acc: [0.8 0.8 0.8 0.8 0.8 0.8]
# step: 540 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 570 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 600 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 630 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 660 	training acc: [0.8 0.8 0.8 0.8 0.8 0.8]
# step: 690 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 720 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 750 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 780 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 810 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 840 	training acc: [0.8 0.9 0.9 0.9 0.9 0.9]
# step: 870 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 900 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 930 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 960 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 990 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1000 	test acc: [0.945 0.94  0.945 0.945 0.945 0.945 0.945 0.945 0.945 0.945 0.945]
# step: 1020 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1050 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1080 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 1110 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1140 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1170 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 1200 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1230 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1260 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1290 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1320 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1350 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1380 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 1410 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1440 	training acc: [1.  0.9 0.9 0.9 0.9 0.9]
# step: 1470 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1500 	training acc: [0.8 0.7 0.7 0.7 0.7 0.7]
# step: 1500 	test acc: [0.91 0.91 0.91 0.91 0.91 0.91 0.91 0.91 0.91 0.91 0.91]
# step: 1530 	training acc: [0.9 0.9 0.8 0.8 0.8 0.8]
# step: 1560 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1590 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1620 	training acc: [1.  0.9 0.9 0.9 0.9 0.9]
# step: 1650 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1680 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1710 	training acc: [0.9 1.  1.  1.  1.  1. ]
# step: 1740 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1770 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1800 	training acc: [1.  0.9 0.9 0.9 0.9 0.9]
# step: 1830 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1860 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1890 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1920 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1950 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 1980 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 0 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 0 	test acc: [0.955 0.95  0.95  0.95  0.95  0.95  0.95  0.95  0.95  0.95  0.95 ]
# step: 30 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 60 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 90 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 120 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 150 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 180 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 210 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 240 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 270 	training acc: [1.  0.9 0.9 0.9 0.9 0.9]
# step: 300 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 330 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 360 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 390 	training acc: [0.9 0.9 0.9 0.9 0.9 0.9]
# step: 420 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 450 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 480 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 500 	test acc: [0.955 0.95  0.95  0.95  0.95  0.95  0.95  0.95  0.95  0.95  0.95 ]
# step: 510 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 540 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 570 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 600 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 630 	training acc: [1.  0.9 1.  1.  1.  1. ]
# step: 660 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 690 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 720 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 750 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 780 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 810 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 840 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 870 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 900 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 930 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 960 	training acc: [1. 1. 1. 1. 1. 1.]
# step: 990 	training acc: [1.  1.  0.9 0.9 0.9 0.9]
