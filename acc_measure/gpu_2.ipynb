# %%
gpu_idx = 2

# %%
task_nums = [50, 20, 10, 5]
i = gpu_idx
for task_num in task_nums:
    # !python train_net_cross_val.py --epoch 40000 --gpu_index {gpu_idx} --task_num {task_num} --mode 0 --cross_val_id {i}
# Out:
# Namespace(cross_val_idx=2, epoch=40000, gpu_index='2', imgc=3, imgsz=84, k_qry=1, k_spt=1, meta_lr=0.001, mode=0, n_way=2, task_num=50, update_lr=0.01, update_step=5, update_step_test=10)
# Total trainable tensors: 30498
# shuffle DB :train, b:10000, 2-way, 1-shot, 1-query, resize:84
# shuffle DB :val, b:100, 2-way, 1-shot, 1-query, resize:84
# step: 0 	training acc: [0.54 0.56 0.58 0.59 0.56 0.57]
# step: 0 	test acc: [0.49  0.505 0.485 0.475 0.475 0.475 0.475 0.48  0.475 0.48  0.48 ]
# step: 30 	training acc: [0.75 0.68 0.68 0.68 0.7  0.7 ]
# step: 60 	training acc: [0.85 0.73 0.79 0.77 0.75 0.78]
# step: 90 	training acc: [0.84 0.71 0.77 0.77 0.78 0.77]
# step: 120 	training acc: [0.9  0.88 0.88 0.89 0.89 0.89]
# step: 150 	training acc: [0.92 0.86 0.88 0.87 0.88 0.87]
# step: 180 	training acc: [0.94 0.86 0.87 0.88 0.87 0.88]
# step: 0 	training acc: [0.95 0.96 0.96 0.97 0.96 0.96]
# step: 0 	test acc: [0.915 0.89  0.9   0.905 0.905 0.905 0.905 0.905 0.905 0.905 0.905]
# ...

# %%
task_nums = [50, 20, 10, 5]
i = gpu_idx
for task_num in task_nums:
    # !python train_net_cv2.py --epoch 40000 --gpu_index {gpu_idx} --task_num {task_num} --mode 0 --cross_val_id {i}
# Out:
# Namespace(cross_val_idx=2, epoch=40000, gpu_index='2', imgc=3, imgsz=84, k_qry=1, k_spt=1, meta_lr=0.001, mode=0, n_way=2, task_num=50, update_lr=0.01, update_step=5, update_step_test=10)
# Total trainable tensors: 30498
# shuffle DB :train, b:10000, 2-way, 1-shot, 1-query, resize:84
# shuffle DB :val, b:100, 2-way, 1-shot, 1-query, resize:84
# step: 0 	training acc: [0.51 0.52 0.59 0.6  0.61 0.57]
# step: 0 	test acc: [0.52  0.51  0.5   0.495 0.49  0.475 0.5   0.495 0.49  0.495 0.505]
# step: 30 	training acc: [0.82 0.74 0.79 0.76 0.77 0.77]
# step: 60 	training acc: [0.82 0.79 0.83 0.82 0.82 0.82]
# step: 90 	training acc: [0.88 0.84 0.81 0.82 0.83 0.83]
# step: 120 	training acc: [0.91 0.86 0.83 0.83 0.82 0.82]
# step: 150 	training acc: [0.87 0.82 0.86 0.82 0.84 0.84]
# step: 180 	training acc: [0.97 0.93 0.94 0.94 0.94 0.94]
# step: 0 	training acc: [0.95 0.9  0.87 0.86 0.87 0.87]
# step: 0 	test acc: [0.93  0.905 0.905 0.91  0.915 0.915 0.915 0.915 0.915 0.92  0.92 ]
# ...
